# %%
import pandas as pd
import Bio, os, re
from Bio import AlignIO, SeqIO, pairwise2
from Bio.Seq import Seq 
import pydna
import subprocess
import pysam
from collections import defaultdict
from bs4 import BeautifulSoup

pd.options.display.max_rows = 1000

# %%
path = '/run/user/1701730025/gvfs/smb-share:server=s455fm120,share=share/DIS/LABS/Environmental/WNV/fasta_sequence/'
fasta_file = [path + x for x in os.listdir(path) if x.endswith("_sequence.fasta")]
fasta_file_name = [os.path.basename(x).replace("_sequence.fasta", "")  for x in fasta_file]

# %%
dicts = {}
fasta_dict = {}
for i in range(0, len(fasta_file)):
    dicts[fasta_file_name[i]] = len(SeqIO.read(fasta_file[i], "fasta").seq)
    fasta_dict[fasta_file_name[i]] = fasta_file[i]

# %%
#This is the 
class microbe:
    def __init__(self, forward, reverse, probe, fasta):
        self.forward = forward
        self.reverse = reverse
        self.probe = probe
        self.fasta = fasta
        
    def fr_position(self):
        if Seq(self.forward) in SeqIO.read(self.fasta, "fasta").seq:
            forward_position = SeqIO.read(self.fasta, "fasta").seq.index(Seq(self.forward))    
        elif Seq(self.forward).reverse_complement() in SeqIO.read(self.fasta, "fasta").seq:
            forward_position = SeqIO.read(self.fasta, "fasta").seq.index(Seq(self.forward).reverse_complement())
        else:
            forward_position = "no_forward"
            
        if Seq(self.reverse) in SeqIO.read(self.fasta, "fasta").seq:
            reverse_position = SeqIO.read(self.fasta, "fasta").seq.index(Seq(self.reverse))
        elif Seq(self.reverse).reverse_complement() in SeqIO.read(self.fasta, "fasta").seq:
            reverse_position = SeqIO.read(self.fasta, "fasta").seq.index(Seq(self.reverse).reverse_complement())
        else:
            reverse_position = "no_reverse"
        
        if type(forward_position) == int and type(reverse_position) == int:
            if reverse_position > forward_position:
                amplicon_lenght = reverse_position + len(Seq(self.reverse)) - forward_position + 1
            else:
                amplicon_lenght = forward_position + len(Seq(self.forward)) - reverse_position + 1
            return([forward_position, reverse_position, amplicon_lenght])
        else:
            return([forward_position, reverse_position])

# %%
Anaplasma_phagocytophilum = microbe("GGCATGTAGGCGGTTCGGT", "CACTAGGAATTCCGCTATCCTCTCC", "GCCAGGGCTTAACCCTGGAGCT",\
                                    fasta_dict['Anaplasma_phagocytophilum'])
Powassan_virus = microbe('GTGATGTGGCAGCGCACC', 'CTGCGTCGGGAGCGACCA', 'CCTACTGCGGCAGCACACACAGTG',\
                        fasta_dict['Powassan_virus'])
Borrelia_miyamotoi = microbe('AGCACAAGCTTCATGGACATTGA', 'GAGCTGCTTGAGCACCTTCTC', 'TGTGGGTGCAAATCAGGATGAAGCA',\
                            fasta_dict['Borrelia_miyamotoi'])
Borrelia_burgdorferi = microbe('CCTTCAAGTACTCCAGATCCATTG', 'AACAAAGACGGCAAGTACGATC', 'CAACAGTAGACAAGCTTGA',\
                              fasta_dict['Borrelia_burgdorferi'])
Babesia_microti = microbe('CATCATGCCAGGCCTGTTTG', 'GAAGAAACCACAAGAGCAAATGC', 'TACTACCCATACTGGTCGGTGCTCC',\
                         fasta_dict['Babesia_microti'])
Anaplasma_platys = microbe("GGCATGTAGGCGGTTCGGT", "CACTAGGAATTCCGCTATCCTCTCC", "GCCAGGGCTTAACCCTGGAGCT",\
                                    fasta_dict['Anaplasma_platys'])

# %%
microbe_list = [Anaplasma_phagocytophilum, Powassan_virus, Borrelia_miyamotoi, Borrelia_burgdorferi, Babesia_microti,
               Anaplasma_platys]

# %%
len_dict = {}
for m in range(0, len(microbe_list)):
    len_dict[fasta_file_name[m]] = microbe.fr_position(microbe_list[m])

# %%
len_dict
# Out:
# {'Powassan_virus': [1065588, 1065497, 111],
#  'Babesia_microti': [10384, 10547, 182],
#  'Anaplasma_phagocytophilum': [757086, 757187, 123],
#  'Anaplasma_platys': [9809, 9738, 96],
#  'Borrelia_miyamotoi': [2765, 2880, 139],
#  'Borrelia_burgdorferi': [489, 574, 111]}

# %%
def degenerate_base(base):
    if base == 'Y':
        return 'CT'
    elif base == 'R':
        return 'AG'
    elif base == 'W':
        return 'AT'
    elif base == 'S':
        return 'GC'
    elif base == 'K':
        return 'TG'
    elif base == 'M':
        return 'AC'
    elif base == 'D':
        return 'AGT'
    elif base == 'V':
        return 'ACG'
    elif base == 'H':
        return 'ACT'
    elif base == 'B':
        return 'CGT'
    elif base == 'X' or base == 'N':
        return 'ATGC'
    else:
        return base
    
def is_frp(frp, frp_key):
    frp_bool_list = []
    for i in frp_key:
        frp_bool_list.append(bool(re.match(frp, i, re.IGNORECASE)))
    return [i for (i, v) in zip(frp_key, frp_bool_list) if v][0]

def listfiles(path, extension):
    dirpath = [k for k in os.listdir(path) if extension in k]
    return dirpath

def align_summary(path):
    from Bio import AlignIO
    path = path

    dlist = []
    dlist2 = []

    for file in listfiles(path, "clustalw"):
        alignment = AlignIO.read(open(path + file), "clustal")

        align_dict = {}
        for i in range(0, len(alignment)):
            align_dict[alignment[i].id] = str(alignment[i].seq)

            frp_key = [x for x in align_dict.keys() if re.search("forward|reverse|probe", x, re.IGNORECASE) != None]
            sequence_key = [x for x in list(align_dict.keys()) if x not in frp_key]
            mismatch_dict = defaultdict(dict)
            sequence_dict = defaultdict(dict)

            for primer in frp_key:
                for key in sequence_key:
                    key_list = list(align_dict[key])
                    primer_boolean_list = [x != '-' for x in align_dict[primer]] 
                    filtered_sequence = ''.join([i for (i, v) in zip(key_list, primer_boolean_list) if v])
                    primer_sequence = str(align_dict[primer]).replace("-", "")
                    mismatch_dict[primer][key] = [i+1 for i in range(0, len(primer_sequence)) \
                                                  if filtered_sequence[i].lower() not in degenerate_base(primer_sequence[i]).lower()]
                    sequence_dict[primer][key] = filtered_sequence

            df = pd.DataFrame(mismatch_dict)
            for col in df.columns:
                df[col + '_num'] = df[col].str.len()

            df2 = pd.DataFrame(sequence_dict)
            df2.columns = [x + '_sequence' for x in df2.columns]

        dlist.append(df)
        dlist2.append(df2)

    df3 = pd.concat([pd.concat(dlist), pd.concat(dlist2)], axis=1)
    return df3

# %%
path = '/run/user/1701730025/gvfs/smb-share:server=s455fm120,share=share/DIS/LABS/Environmental/WNV/alignment/ZIKV/'
db = align_summary(path)
db.to_csv(path + 'ZIKV_alignment_2.csv', index = True)

# %%
# Run this cell if you only have one set of primers and probe
df = pd.DataFrame(mismatch_dict)
df['mismatch_forward'] = df[is_frp('forward', frp_key)].str.len()
df['mismatch_reverse'] = df[is_frp('reverse', frp_key)].str.len()
df['mismatch_probe'] = df[is_frp('probe', frp_key)].str.len()
df['mismatch_total'] = df['mismatch_forward'] + df['mismatch_reverse'] + df['mismatch_probe']
df.sort_values(by = ['mismatch_total'], ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-33301f5f679c> in <module>
#       1 # Run this cell if you only have one set of primers and probe
# ----> 2 df = pd.DataFrame(mismatch_dict)
#       3 df['mismatch_forward'] = df[is_frp('forward', frp_key)].str.len()
#       4 df['mismatch_reverse'] = df[is_frp('reverse', frp_key)].str.len()
#       5 df['mismatch_probe'] = df[is_frp('probe', frp_key)].str.len()
#
# NameError: name 'mismatch_dict' is not defined

# %%
db
# Out:
#                    ZIKE_forward        ZIKNS_probe ZIKE_reverse    ZIKE_probe  \
# KX830960.1   [7, 9, 12, 15, 21]  [3, 6, 9, 15, 21]     [11, 23]  [15, 18, 21]
# KX377335.1   [7, 9, 12, 15, 21]  [3, 6, 9, 15, 21]     [11, 23]  [15, 18, 21]
# LC002520.1   [7, 9, 12, 15, 21]  [3, 6, 9, 15, 21]     [11, 23]  [15, 18, 21]
# KU955595.1               [7, 9]        [9, 15, 21]   [2, 3, 23]    [3, 6, 21]
# KU955592.1               [7, 9]        [9, 15, 21]   [2, 3, 23]    [3, 6, 21]
# KU955591.1               [7, 9]        [9, 15, 21]   [2, 3, 23]    [3, 6, 21]
# KX197205.1                   []                 []           []            []
# KJ776791.2                   []                 []           []            []
# KX377337.1                   []                 []           []            []
# KX262887.1                   []                 []           []            []
# KX253996.1                   []                [5]           []            []
# KX117076.1                   []                [5]           []            []
# KU820899.2                   []                [5]           []            []
# KX247646.1                   []                [4]         [21]            []
# KU509998.3                   []                 []           []            []
# KU681081.3                   []                 []           []            []
# KU955593.1              [9, 15]               [18]           []            []
# KU681082.3                   []                [6]           []            []
# KX377336.1                   []                [9]          [2]           [3]
# MW015936.1                 [15]               [18]           []            []
# MH158236.1              [9, 15]               [18]           []            []
# MH544701.2                   []                [4]         [21]            []
# KY989971.1                   []                [4]         [21]            []
# MN577543.1                   []                [4]         [21]            []
# KU820897.5                   []                [4]         [21]            []
# KX893855.1                   []                [4]         [21]            []
# KX702400.1                   []                [4]         [21]            []
# MT507050.1                   []                 []           []            []
# MT507049.1                   []                 []           []            []
# MT507047.1                   []                 []           []            []
# MT507048.1                   []                 []           []            []
# MN577550.1                   []                 []           []            []
# KY328289.1                   []                 []          [3]            []
# MH675630.1                   []                 []          [3]            []
# MH675629.1                   []                 []          [3]            []
# MK566202.1                   []               [21]           []            []
# MF073359.1                   []               [21]           []            []
# MF073358.1                   []                 []           []            []
# MG827392.1                   []                 []           []            []
# KX280026.1                   []                 []           []            []
# KX806557.3                   []                 []           []            []
# KU926309.2                   []                 []           []            []
# KY272991.1                   []                 []         [23]            []
# MF783073.1                   []                 []           []            []
# KX197192.1                   []                 []           []            []
# MF352141.1                   []                [4]           []            []
# KU926310.2                   []                 []           []            []
# MH055376.1                   []                [5]           []            []
# MG674718.1                   []                [5]           []            []
# MF073357.1                   []                 []           []            []
# KY348640.1                   []                 []           []            []
# MH675628.1                   []                 []           []            []
# MH675627.1                   []                 []           []            []
# MH675624.1                   []                 []           []            []
# MH158237.1                   []                 []           []            []
# MH675623.1                   []                 []           []            []
# MH675622.1                   []                 []           []            []
# MH675620.1                   []                 []           []            []
# MH675625.1                   []                 []           []            []
# MH675619.1                   []                 []           []            []
# MH675621.1                   []                 []           []            []
# MH675626.1                   []                 []           []            []
# MN566108.1                   []                 []           []            []
# MN566107.1                   []                 []           []            []
# MN566106.1                   []                 []           []            []
# MN566105.1                   []                 []           []            []
# MN566104.1                   []                 []           []            []
# MF783072.1                   []                 []           []            []
# KY415991.1                   []                 []           []            []
# KY415990.1                   []                 []           []            []
# KY415989.1                   []                 []           []            []
# KY415988.1                   []                 []           []            []
# KY415987.1                   []                 []           []            []
# KY415986.1                   []                 []           []            []
# MF384325.1                   []                 []           []            []
# KX051563.1                   []                 []           []            []
# NC_035889.1                  []                 []           []            []
# KU527068.1                   []                 []           []            []
# MT636065.1                   []                 []           []            []
# KX879604.1                   []                 []           []            []
# KX879603.1                   []                 []           []            []
# LC191864.1                   []                 []           []            []
# MN577544.1                   []                [4]         [21]            []
# MG807646.1                   []                 []          [3]          [18]
# MG548661.1                   []                 []         [21]            []
# MG548660.1                   []                 []         [21]            []
# MF996804.1                   []                 []         [21]            []
# MG807647.1                   []                 []           []          [15]
# MN611472.1                   []                [9]           []            []
# KY766069.1                   []                 []           []            []
# KX051562.1                   []                 []           []          [18]
# KY272987.1                   []                 []         [14]            []
# MT505350.1               [7, 9]        [9, 15, 21]   [2, 3, 23]    [3, 6, 21]
# MT505349.1               [7, 9]        [9, 15, 21]   [2, 3, 23]    [3, 6, 21]
# MG758786.1               [7, 9]        [9, 15, 21]   [2, 3, 23]    [3, 6, 21]
# MG758785.1               [7, 9]        [9, 15, 21]   [2, 3, 23]    [3, 6, 21]
# KX198134.2               [7, 9]        [9, 15, 21]   [2, 3, 23]    [3, 6, 21]
# MF510857.1               [7, 9]        [9, 15, 21]   [2, 3, 23]    [3, 6, 21]
# KY989511.1   [7, 9, 12, 15, 21]  [3, 6, 9, 15, 21]     [11, 23]  [15, 18, 21]
#
#             ZIKNS_reverse ZIKNS_forward  ZIKE_forward_num  ZIKNS_probe_num  \
# KX830960.1             []          [17]                 5                5
# KX377335.1             []          [17]                 5                5
# LC002520.1             []          [17]                 5                5
# KU955595.1             []      [11, 17]                 2                3
# KU955592.1             []      [11, 17]                 2                3
# KU955591.1             []      [11, 17]                 2                3
# KX197205.1             []            []                 0                0
# KJ776791.2             []            []                 0                0
# KX377337.1             []            []                 0                0
# KX262887.1             []            []                 0                0
# KX253996.1             []            []                 0                1
# KX117076.1             []            []                 0                1
# KU820899.2             []            []                 0                1
# KX247646.1             []            []                 0                1
# KU509998.3             []            []                 0                0
# KU681081.3             []            []                 0                0
# KU955593.1             []            []                 2                1
# KU681082.3             []            []                 0                1
# KX377336.1             []          [15]                 0                1
# MW015936.1             []            []                 1                1
# MH158236.1             []            []                 2                1
# MH544701.2             []            []                 0                1
# KY989971.1             []            []                 0                1
# MN577543.1             []            []                 0                1
# KU820897.5             []            []                 0                1
# KX893855.1             []            []                 0                1
# KX702400.1             []            []                 0                1
# MT507050.1             []            []                 0                0
# MT507049.1             []            []                 0                0
# MT507047.1             []            []                 0                0
# MT507048.1             []            []                 0                0
# MN577550.1             []            []                 0                0
# KY328289.1             []            []                 0                0
# MH675630.1             []            []                 0                0
# MH675629.1             []            []                 0                0
# MK566202.1             []            []                 0                1
# MF073359.1             []            []                 0                1
# MF073358.1             []            []                 0                0
# MG827392.1             []            []                 0                0
# KX280026.1             []            []                 0                0
# KX806557.3             []            []                 0                0
# KU926309.2             []            []                 0                0
# KY272991.1             []            []                 0                0
# MF783073.1             []            []                 0                0
# KX197192.1             []            []                 0                0
# MF352141.1             []            []                 0                1
# KU926310.2             []            []                 0                0
# MH055376.1             []            []                 0                1
# MG674718.1             []            []                 0                1
# MF073357.1             []            []                 0                0
# KY348640.1             []            []                 0                0
# MH675628.1             []            []                 0                0
# MH675627.1             []            []                 0                0
# MH675624.1             []            []                 0                0
# MH158237.1             []            []                 0                0
# MH675623.1             []            []                 0                0
# MH675622.1             []            []                 0                0
# MH675620.1             []            []                 0                0
# MH675625.1             []            []                 0                0
# MH675619.1             []            []                 0                0
# MH675621.1             []            []                 0                0
# MH675626.1             []            []                 0                0
# MN566108.1             []            []                 0                0
# MN566107.1             []            []                 0                0
# MN566106.1             []            []                 0                0
# MN566105.1             []            []                 0                0
# MN566104.1             []            []                 0                0
# MF783072.1             []            []                 0                0
# KY415991.1             []            []                 0                0
# KY415990.1             []            []                 0                0
# KY415989.1             []            []                 0                0
# KY415988.1             []            []                 0                0
# KY415987.1             []            []                 0                0
# KY415986.1             []            []                 0                0
# MF384325.1             []            []                 0                0
# KX051563.1             []            []                 0                0
# NC_035889.1            []            []                 0                0
# KU527068.1             []            []                 0                0
# MT636065.1             []            []                 0                0
# KX879604.1             []            []                 0                0
# KX879603.1             []            []                 0                0
# LC191864.1             []            []                 0                0
# MN577544.1             []            []                 0                1
# MG807646.1             []            []                 0                0
# MG548661.1             []            []                 0                0
# MG548660.1             []            []                 0                0
# MF996804.1             []            []                 0                0
# MG807647.1             []            []                 0                0
# MN611472.1             []            []                 0                1
# KY766069.1             []            []                 0                0
# KX051562.1             []            []                 0                0
# KY272987.1             []            []                 0                0
# MT505350.1             []      [11, 17]                 2                3
# MT505349.1             []      [11, 17]                 2                3
# MG758786.1             []      [11, 17]                 2                3
# MG758785.1             []      [11, 17]                 2                3
# KX198134.2             []      [11, 17]                 2                3
# MF510857.1             []      [11, 17]                 2                3
# KY989511.1             []          [17]                 5                5
#
#              ZIKE_reverse_num  ZIKE_probe_num  ZIKNS_reverse_num  \
# KX830960.1                  2               3                  0
# KX377335.1                  2               3                  0
# LC002520.1                  2               3                  0
# KU955595.1                  3               3                  0
# KU955592.1                  3               3                  0
# KU955591.1                  3               3                  0
# KX197205.1                  0               0                  0
# KJ776791.2                  0               0                  0
# KX377337.1                  0               0                  0
# KX262887.1                  0               0                  0
# KX253996.1                  0               0                  0
# KX117076.1                  0               0                  0
# KU820899.2                  0               0                  0
# KX247646.1                  1               0                  0
# KU509998.3                  0               0                  0
# KU681081.3                  0               0                  0
# KU955593.1                  0               0                  0
# KU681082.3                  0               0                  0
# KX377336.1                  1               1                  0
# MW015936.1                  0               0                  0
# MH158236.1                  0               0                  0
# MH544701.2                  1               0                  0
# KY989971.1                  1               0                  0
# MN577543.1                  1               0                  0
# KU820897.5                  1               0                  0
# KX893855.1                  1               0                  0
# KX702400.1                  1               0                  0
# MT507050.1                  0               0                  0
# MT507049.1                  0               0                  0
# MT507047.1                  0               0                  0
# MT507048.1                  0               0                  0
# MN577550.1                  0               0                  0
# KY328289.1                  1               0                  0
# MH675630.1                  1               0                  0
# MH675629.1                  1               0                  0
# MK566202.1                  0               0                  0
# MF073359.1                  0               0                  0
# MF073358.1                  0               0                  0
# MG827392.1                  0               0                  0
# KX280026.1                  0               0                  0
# KX806557.3                  0               0                  0
# KU926309.2                  0               0                  0
# KY272991.1                  1               0                  0
# MF783073.1                  0               0                  0
# KX197192.1                  0               0                  0
# MF352141.1                  0               0                  0
# KU926310.2                  0               0                  0
# MH055376.1                  0               0                  0
# MG674718.1                  0               0                  0
# MF073357.1                  0               0                  0
# KY348640.1                  0               0                  0
# MH675628.1                  0               0                  0
# MH675627.1                  0               0                  0
# MH675624.1                  0               0                  0
# MH158237.1                  0               0                  0
# MH675623.1                  0               0                  0
# MH675622.1                  0               0                  0
# MH675620.1                  0               0                  0
# MH675625.1                  0               0                  0
# MH675619.1                  0               0                  0
# MH675621.1                  0               0                  0
# MH675626.1                  0               0                  0
# MN566108.1                  0               0                  0
# MN566107.1                  0               0                  0
# MN566106.1                  0               0                  0
# MN566105.1                  0               0                  0
# MN566104.1                  0               0                  0
# MF783072.1                  0               0                  0
# KY415991.1                  0               0                  0
# KY415990.1                  0               0                  0
# KY415989.1                  0               0                  0
# KY415988.1                  0               0                  0
# KY415987.1                  0               0                  0
# KY415986.1                  0               0                  0
# MF384325.1                  0               0                  0
# KX051563.1                  0               0                  0
# NC_035889.1                 0               0                  0
# KU527068.1                  0               0                  0
# MT636065.1                  0               0                  0
# KX879604.1                  0               0                  0
# KX879603.1                  0               0                  0
# LC191864.1                  0               0                  0
# MN577544.1                  1               0                  0
# MG807646.1                  1               1                  0
# MG548661.1                  1               0                  0
# MG548660.1                  1               0                  0
# MF996804.1                  1               0                  0
# MG807647.1                  0               1                  0
# MN611472.1                  0               0                  0
# KY766069.1                  0               0                  0
# KX051562.1                  0               1                  0
# KY272987.1                  1               0                  0
# MT505350.1                  3               3                  0
# MT505349.1                  3               3                  0
# MG758786.1                  3               3                  0
# MG758785.1                  3               3                  0
# KX198134.2                  3               3                  0
# MF510857.1                  3               3                  0
# KY989511.1                  2               3                  0
#
#              ZIKNS_forward_num    ZIKE_forward_sequence  \
# KX830960.1                   1  aagtttacgtgttctaagaagat
# KX377335.1                   1  aagtttacgtgttctaagaagat
# LC002520.1                   1  aagtttacgtgttctaagaagat
# KU955595.1                   2  aagtttacgtgctccaagaaaat
# KU955592.1                   2  aagtttacgtgctccaagaaaat
# KU955591.1                   2  aagtttacgtgctccaagaaaat
# KX197205.1                   0  aagtttgcatgctccaagaaaat
# KJ776791.2                   0  aagtttgcatgctccaagaaaat
# KX377337.1                   0  aagtttgcatgctccaagaaaat
# KX262887.1                   0  aagtttgcatgctccaagaaaat
# KX253996.1                   0  aagtttgcatgctccaagaaaat
# KX117076.1                   0  aagtttgcatgctccaagaaaat
# KU820899.2                   0  aagtttgcatgctccaagaaaat
# KX247646.1                   0  aagtttgcatgctccaagaaaat
# KU509998.3                   0  aagtttgcatgctccaagaaaat
# KU681081.3                   0  aagtttgcatgctccaagaaaat
# KU955593.1                   0  aagtttgcttgctctaagaaaat
# KU681082.3                   0  aagtttgcatgctccaagaaaat
# KX377336.1                   1  aagtttgcatgctccaagaaaat
# MW015936.1                   0  aagtttgcatgctctaagaaaat
# MH158236.1                   0  aagtttgcttgctctaagaaaat
# MH544701.2                   0  aagtttgcatgctccaagaaaat
# KY989971.1                   0  aagtttgcatgctccaagaaaat
# MN577543.1                   0  aagtttgcatgctccaagaaaat
# KU820897.5                   0  aagtttgcatgctccaagaaaat
# KX893855.1                   0  aagtttgcatgctccaagaaaat
# KX702400.1                   0  aagtttgcatgctccaagaaaat
# MT507050.1                   0  aagtttgcatgctccaagaaaat
# MT507049.1                   0  aagtttgcatgctccaagaaaat
# MT507047.1                   0  aagtttgcatgctccaagaaaat
# MT507048.1                   0  aagtttgcatgctccaagaaaat
# MN577550.1                   0  aagtttgcatgctccaagaaaat
# KY328289.1                   0  aagtttgcatgctccaagaaaat
# MH675630.1                   0  aagtttgcatgctccaagaaaat
# MH675629.1                   0  aagtttgcatgctccaagaaaat
# MK566202.1                   0  aagtttgcatgctccaagaaaat
# MF073359.1                   0  aagtttgcatgctccaagaaaat
# MF073358.1                   0  aagtttgcatgctccaagaaaat
# MG827392.1                   0  aagtttgcatgctccaagaaaat
# KX280026.1                   0  aagtttgcatgctccaagaaaat
# KX806557.3                   0  aagtttgcatgctccaagaaaat
# KU926309.2                   0  aagtttgcatgctccaagaaaat
# KY272991.1                   0  aagtttgcatgctccaagaaaat
# MF783073.1                   0  aagtttgcatgctccaagaaaat
# KX197192.1                   0  aagtttgcatgctccaagaaaat
# MF352141.1                   0  aagtttgcatgctccaagaaaat
# KU926310.2                   0  aagtttgcatgctccaagaaaat
# MH055376.1                   0  aagtttgcatgctccaagaaaat
# MG674718.1                   0  aagtttgcatgctccaagaaaat
# MF073357.1                   0  aagtttgcatgctccaagaaaat
# KY348640.1                   0  aagtttgcatgctccaagaaaat
# MH675628.1                   0  aagtttgcatgctccaagaaaat
# MH675627.1                   0  aagtttgcatgctccaagaaaat
# MH675624.1                   0  aagtttgcatgctccaagaaaat
# MH158237.1                   0  aagtttgcatgctccaagaaaat
# MH675623.1                   0  aagtttgcatgctccaagaaaat
# MH675622.1                   0  aagtttgcatgctccaagaaaat
# MH675620.1                   0  aagtttgcatgctccaagaaaat
# MH675625.1                   0  aagtttgcatgctccaagaaaat
# MH675619.1                   0  aagtttgcatgctccaagaaaat
# MH675621.1                   0  aagtttgcatgctccaagaaaat
# MH675626.1                   0  aagtttgcatgctccaagaaaat
# MN566108.1                   0  aagtttgcatgctccaagaaaat
# MN566107.1                   0  aagtttgcatgctccaagaaaat
# MN566106.1                   0  aagtttgcatgctccaagaaaat
# MN566105.1                   0  aagtttgcatgctccaagaaaat
# MN566104.1                   0  aagtttgcatgctccaagaaaat
# MF783072.1                   0  aagtttgcatgctccaagaaaat
# KY415991.1                   0  aagtttgcatgctccaagaaaat
# KY415990.1                   0  aagtttgcatgctccaagaaaat
# KY415989.1                   0  aagtttgcatgctccaagaaaat
# KY415988.1                   0  aagtttgcatgctccaagaaaat
# KY415987.1                   0  aagtttgcatgctccaagaaaat
# KY415986.1                   0  aagtttgcatgctccaagaaaat
# MF384325.1                   0  aagtttgcatgctccaagaaaat
# KX051563.1                   0  aagtttgcatgctccaagaaaat
# NC_035889.1                  0  aagtttgcatgctccaagaaaat
# KU527068.1                   0  aagtttgcatgctccaagaaaat
# MT636065.1                   0  aagtttgcatgctccaagaaaat
# KX879604.1                   0  aagtttgcatgctccaagaaaat
# KX879603.1                   0  aagtttgcatgctccaagaaaat
# LC191864.1                   0  aagtttgcatgctccaagaaaat
# MN577544.1                   0  aagtttgcatgctccaagaaaat
# MG807646.1                   0  aagtttgcatgctccaagaaaat
# MG548661.1                   0  aagtttgcatgctccaagaaaat
# MG548660.1                   0  aagtttgcatgctccaagaaaat
# MF996804.1                   0  aagtttgcatgctccaagaaaat
# MG807647.1                   0  aagtttgcatgctccaagaaaat
# MN611472.1                   0  aagtttgcatgctccaagaaaat
# KY766069.1                   0  aagtttgcatgctccaagaaaat
# KX051562.1                   0  aagtttgcatgctccaagaaaat
# KY272987.1                   0  aagtttgcatgctccaagaaaat
# MT505350.1                   2  aagtttacgtgctccaagaaaat
# MT505349.1                   2  aagtttacgtgctccaagaaaat
# MG758786.1                   2  aagtttacgtgctccaagaaaat
# MG758785.1                   2  aagtttacgtgctccaagaaaat
# KX198134.2                   2  aagtttacgtgctccaagaaaat
# MF510857.1                   2  aagtttacgtgctccaagaaaat
# KY989511.1                   1  aagtttacgtgttctaagaagat
#
#                   ZIKNS_probe_sequence    ZIKE_reverse_sequence  \
# KX830960.1   tttcgagcaaaagacggctgctggt  atctggagtatcggataatgcta
# KX377335.1   tttcgagcaaaagacggctgctggt  atctggagtatcggataatgcta
# LC002520.1   tttcgagcaaaagacggctgctggt  atctggagtatcggataatgcta
# KU955595.1   ttccgggcgaaagacggctgctggt  acttggagtaccggataatgcta
# KU955592.1   ttccgggcgaaagacggctgctggt  acttggagtaccggataatgcta
# KU955591.1   ttccgggcgaaagacggctgctggt  acttggagtaccggataatgcta
# KX197205.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KJ776791.2   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KX377337.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KX262887.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KX253996.1   ttccaggctaaagatggctgttggt  atctggagtaccggataatgctg
# KX117076.1   ttccaggctaaagatggctgttggt  atctggagtaccggataatgctg
# KU820899.2   ttccaggctaaagatggctgttggt  atctggagtaccggataatgctg
# KX247646.1   ttctgggctaaagatggctgttggt  atctggagtaccggataatgttg
# KU509998.3   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KU681081.3   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KU955593.1   ttccgggctaaagatggttgttggt  atctggagtaccggataatgctg
# KU681082.3   ttccgagctaaagatggctgttggt  atctggagtaccggataatgctg
# KX377336.1   ttccgggcaaaagatggctgttggt  acctggagtaccggataatgctg
# MW015936.1   ttccgggctaaagatggttgttggt  atctggagtaccggataatgctg
# MH158236.1   ttccgggctaaagatggttgttggt  atctggagtaccggataatgctg
# MH544701.2   ttctgggctaaagatggctgttggt  atctggagtaccggataatgttg
# KY989971.1   ttctgggctaaagatggctgttggt  atctggagtaccggataatgttg
# MN577543.1   ttctgggctaaagatggctgttggt  atctggagtaccggataatgttg
# KU820897.5   ttctgggctaaagatggctgttggt  atctggagtaccggataatgttg
# KX893855.1   ttctgggctaaagatggctgttggt  atctggagtaccggataatgttg
# KX702400.1   ttctgggctaaagatggctgttggt  atctggagtaccggataatgttg
# MT507050.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MT507049.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MT507047.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MT507048.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MN577550.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KY328289.1   ttccgggctaaagatggctgttggt  atttggagtaccggataatgctg
# MH675630.1   ttccgggctaaagatggctgttggt  atttggagtaccggataatgctg
# MH675629.1   ttccgggctaaagatggctgttggt  atttggagtaccggataatgctg
# MK566202.1   ttccgggctaaagatggctgctggt  atctggagtaccggataatgctg
# MF073359.1   ttccgggctaaagatggctgctggt  atctggagtaccggataatgctg
# MF073358.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MG827392.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KX280026.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KX806557.3   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KU926309.2   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KY272991.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgcta
# MF783073.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KX197192.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MF352141.1   ttctgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KU926310.2   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MH055376.1   ttccaggctaaagatggctgttggt  atctggagtaccggataatgctg
# MG674718.1   ttccaggctaaagatggctgttggt  atctggagtaccggataatgctg
# MF073357.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KY348640.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MH675628.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MH675627.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MH675624.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MH158237.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MH675623.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MH675622.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MH675620.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MH675625.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MH675619.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MH675621.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MH675626.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MN566108.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MN566107.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MN566106.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MN566105.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MN566104.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MF783072.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KY415991.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KY415990.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KY415989.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KY415988.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KY415987.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KY415986.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MF384325.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KX051563.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# NC_035889.1  ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KU527068.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MT636065.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KX879604.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KX879603.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# LC191864.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MN577544.1   ttctgggctaaagatggctgttggt  atctggagtaccggataatgttg
# MG807646.1   ttccgggctaaagatggctgttggt  atttggagtaccggataatgctg
# MG548661.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgttg
# MG548660.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgttg
# MF996804.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgttg
# MG807647.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# MN611472.1   ttccgggcaaaagatggctgttggt  atctggagtaccggataatgctg
# KY766069.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KX051562.1   ttccgggctaaagatggctgttggt  atctggagtaccggataatgctg
# KY272987.1   ttccgggctaaagatggctgttggt  atctggagtaccgaataatgctg
# MT505350.1   ttccgggcgaaagacggctgctggt  acttggagtaccggataatgcta
# MT505349.1   ttccgggcgaaagacggctgctggt  acttggagtaccggataatgcta
# MG758786.1   ttccgggcgaaagacggctgctggt  acttggagtaccggataatgcta
# MG758785.1   ttccgggcgaaagacggctgctggt  acttggagtaccggataatgcta
# KX198134.2   ttccgggcgaaagacggctgctggt  acttggagtaccggataatgcta
# MF510857.1   ttccgggcaaaagacggctgctggt  acttggagtaccggataatgcta
# KY989511.1   tttcgagcaaaagacggctgctggt  atctggagtatcggataatgcta
#
#                  ZIKE_probe_sequence ZIKNS_reverse_sequence  \
# KX830960.1   accgggaagagcattcaaccgga    tggaatggagataaggccc
# KX377335.1   accgggaagagcattcaaccgga    tggaatggagataaggccc
# LC002520.1   accgggaagagcattcaaccgga    tggaatggagataaggccc
# KU955595.1   acaggcaagagcatccagccgga    tggaatggagataaggccc
# KU955592.1   acaggcaagagcatccagccgga    tggaatggagataaggccc
# KU955591.1   acaggcaagagcatccagccgga    tggaatggagataaggccc
# KX197205.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KJ776791.2   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX377337.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX262887.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX253996.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX117076.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KU820899.2   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX247646.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KU509998.3   accgggaagagcatccagccaga    tggaatggagataaggccc
# KU681081.3   accgggaagagcatccagccaga    tggaatggagataaggccc
# KU955593.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KU681082.3   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX377336.1   actgggaagagcatccagccaga    tggaatggagataaggccc
# MW015936.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH158236.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH544701.2   accgggaagagcatccagccaga    tggaatggagataaggccc
# KY989971.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MN577543.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KU820897.5   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX893855.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX702400.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MT507050.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MT507049.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MT507047.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MT507048.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MN577550.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KY328289.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH675630.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH675629.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MK566202.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MF073359.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MF073358.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MG827392.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX280026.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX806557.3   accgggaagagcatccagccaga    tggaatggagataaggccc
# KU926309.2   accgggaagagcatccagccaga    tggaatggagataaggccc
# KY272991.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MF783073.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX197192.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MF352141.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KU926310.2   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH055376.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MG674718.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MF073357.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KY348640.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH675628.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH675627.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH675624.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH158237.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH675623.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH675622.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH675620.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH675625.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH675619.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH675621.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MH675626.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MN566108.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MN566107.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MN566106.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MN566105.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MN566104.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MF783072.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KY415991.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KY415990.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KY415989.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KY415988.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KY415987.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KY415986.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MF384325.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX051563.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# NC_035889.1  accgggaagagcatccagccaga    tggaatggagataaggccc
# KU527068.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MT636065.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX879604.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX879603.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# LC191864.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MN577544.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MG807646.1   accgggaagagcatccaaccaga    tggaatggagataaggccc
# MG548661.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MG548660.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MF996804.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MG807647.1   accgggaagagcattcagccaga    tggaatggagataaggccc
# MN611472.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KY766069.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# KX051562.1   accgggaagagcatccaaccaga    tggaatggagataaggccc
# KY272987.1   accgggaagagcatccagccaga    tggaatggagataaggccc
# MT505350.1   acaggcaagagcatccagccgga    tggaatggagataaggccc
# MT505349.1   acaggcaagagcatccagccgga    tggaatggagataaggccc
# MG758786.1   acaggcaagagcatccagccgga    tggaatggagataaggccc
# MG758785.1   acaggcaagagcatccagccgga    tggaatggagataaggccc
# KX198134.2   acaggcaagagcatccagccgga    tggaatggagataaggccc
# MF510857.1   acaggcaagagcatccagccgga    tggaatggagataaggccc
# KY989511.1   accgggaagagcattcaaccgga    tggaatggagataaggccc
#
#             ZIKNS_forward_sequence
# KX830960.1      gcacaatgcccccactat
# KX377335.1      gcacaatgcccccactat
# LC002520.1      gcacaatgcccccactat
# KU955595.1      gcacaatgcctccactat
# KU955592.1      gcacaatgcctccactat
# KU955591.1      gcacaatgcctccactat
# KX197205.1      gcacaatgcccccactgt
# KJ776791.2      gcacaatgcccccactgt
# KX377337.1      gcacaatgcccccactgt
# KX262887.1      gcacaatgcccccactgt
# KX253996.1      gcacaatgcccccactgt
# KX117076.1      gcacaatgcccccactgt
# KU820899.2      gcacaatgcccccactgt
# KX247646.1      gcacaatgcccccactgt
# KU509998.3      gcacaatgcccccactgt
# KU681081.3      gcacaatgcccccactgt
# KU955593.1      gcacaatgcccccactgt
# KU681082.3      gcacaatgcccccactgt
# KX377336.1      gcacaatgcccccattgt
# MW015936.1      gcacaatgcccccactgt
# MH158236.1      gcacaatgcccccactgt
# MH544701.2      gcacaatgcccccactgt
# KY989971.1      gcacaatgcccccactgt
# MN577543.1      gcacaatgcccccactgt
# KU820897.5      gcacaatgcccccactgt
# KX893855.1      gcacaatgcccccactgt
# KX702400.1      gcacaatgcccccactgt
# MT507050.1      gcacaatgcccccactgt
# MT507049.1      gcacaatgcccccactgt
# MT507047.1      gcacaatgcccccactgt
# MT507048.1      gcacaatgcccccactgt
# MN577550.1      gcacaatgcccccactgt
# KY328289.1      gcacaatgcccccactgt
# MH675630.1      gcacaatgcccccactgt
# MH675629.1      gcacaatgcccccactgt
# MK566202.1      gcacaatgcccccactgt
# MF073359.1      gcacaatgcccccactgt
# MF073358.1      gcacaatgcccccactgt
# MG827392.1      gcacaatgcccccactgt
# KX280026.1      gcacaatgcccccactgt
# KX806557.3      gcacaatgcccccactgt
# KU926309.2      gcacaatgcccccactgt
# KY272991.1      gcacaatgcccccactgt
# MF783073.1      gcacaatgcccccactgt
# KX197192.1      gcacaatgcccccactgt
# MF352141.1      gcacaatgcccccactgt
# KU926310.2      gcacaatgcccccactgt
# MH055376.1      gcacaatgcccccactgt
# MG674718.1      gcacaatgcccccactgt
# MF073357.1      gcacaatgcccccactgt
# KY348640.1      gcacaatgcccccactgt
# MH675628.1      gcacaatgcccccactgt
# MH675627.1      gcacaatgcccccactgt
# MH675624.1      gcacaatgcccccactgt
# MH158237.1      gcacaatgcccccactgt
# MH675623.1      gcacaatgcccccactgt
# MH675622.1      gcacaatgcccccactgt
# MH675620.1      gcacaatgcccccactgt
# MH675625.1      gcacaatgcccccactgt
# MH675619.1      gcacaatgcccccactgt
# MH675621.1      gcacaatgcccccactgt
# MH675626.1      gcacaatgcccccactgt
# MN566108.1      gcacaatgcccccactgt
# MN566107.1      gcacaatgcccccactgt
# MN566106.1      gcacaatgcccccactgt
# MN566105.1      gcacaatgcccccactgt
# MN566104.1      gcacaatgcccccactgt
# MF783072.1      gcacaatgcccccactgt
# KY415991.1      gcacaatgcccccactgt
# KY415990.1      gcacaatgcccccactgt
# KY415989.1      gcacaatgcccccactgt
# KY415988.1      gcacaatgcccccactgt
# KY415987.1      gcacaatgcccccactgt
# KY415986.1      gcacaatgcccccactgt
# MF384325.1      gcacaatgcccccactgt
# KX051563.1      gcacaatgcccccactgt
# NC_035889.1     gcacaatgcccccactgt
# KU527068.1      gcacaatgcccccactgt
# MT636065.1      gcacaatgcccccactgt
# KX879604.1      gcacaatgcccccactgt
# KX879603.1      gcacaatgcccccactgt
# LC191864.1      gcacaatgcccccactgt
# MN577544.1      gcacaatgcccccactgt
# MG807646.1      gcacaatgcccccactgt
# MG548661.1      gcacaatgcccccactgt
# MG548660.1      gcacaatgcccccactgt
# MF996804.1      gcacaatgcccccactgt
# MG807647.1      gcacaatgcccccactgt
# MN611472.1      gcacaatgcccccactgt
# KY766069.1      gcacaatgcccccactgt
# KX051562.1      gcacaatgcccccactgt
# KY272987.1      gcacaatgcccccactgt
# MT505350.1      gcacaatgcctccactat
# MT505349.1      gcacaatgcctccactat
# MG758786.1      gcacaatgcctccactat
# MG758785.1      gcacaatgcctccactat
# KX198134.2      gcacaatgcctccactat
# MF510857.1      gcacaatgcctccactat
# KY989511.1      gcacaatgcccccactat

# %%
bampath = "/run/user/1701730025/gvfs/smb-share:server=s455fm120,share=share/DIS/LABS/Environmental/WNV/fasta_sequence/WNV_BAM/"
samfile = pysam.AlignmentFile(bampath + "SRR7784795_align_dedup_sort.bam", "rb")

# %%
samfile = pysam.AlignmentFile(bampath + "SRR7784795_align_dedup_sort.bam", "rb" )
xx = 0
for pileupcolumn in samfile.pileup("NC_009942.1", 1, 500):
    xx = xx + 1
    for pileupread in pileupcolumn.pileups:
        if not pileupread.is_del and not pileupread.is_refskip and pileupcolumn.pos in indices:
                # query position is None if is_del or is_refskip is set.
                print ('\tbase in read %s = %s' %
                    (pileupread.alignment.query_name,
                    pileupread.alignment.query_sequence[pileupread.query_position]))
samfile.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-00e7e81b595d> in <module>
#       4     xx = xx + 1
#       5     for pileupread in pileupcolumn.pileups:
# ----> 6         if not pileupread.is_del and not pileupread.is_refskip and pileupcolumn.pos in  indices:
#       7                 # query position is None if is_del or is_refskip is set.
#       8                 print ('\tbase in read %s = %s' %
#
# NameError: name 'indices' is not defined

# %%
poslist = []
countlist = []
base_list = []
unique_base_count = []

samfile = pysam.AlignmentFile(bampath + "SRR7784795_align_dedup_sort.bam", "rb" )
for pileupcolumn in samfile.pileup("NC_009942.1", 1, 11029):
    poslist.append(pileupcolumn.pos)
    countlist.append(pileupcolumn.n)
    
    templist = []
    for pileupread in pileupcolumn.pileups:
        if not pileupread.is_del and not pileupread.is_refskip:
            templist.append(pileupread.alignment.query_sequence[pileupread.query_position])
    base_list.append(templist)
    unique_base_count.append(len(set(templist)))

# %%
indices = [i for i, x in enumerate(unique_base_count) if x == 3]

# %%
print(indices)
# Out:
# [186, 187, 201, 213, 216, 218, 221, 222, 238, 244, 250, 258, 268, 269, 288, 292, 295, 299, 302, 303, 313, 324, 330, 331, 332, 349, 353, 363, 367, 382, 390, 396, 409, 413, 416, 426, 433, 450, 456, 467, 488, 489, 490, 505, 511, 512, 515, 536, 538, 541, 543, 554, 555, 556, 559, 566, 571, 583, 592, 597, 598, 599, 601, 608, 618, 624, 630, 636, 648, 670, 678, 697, 702, 705, 709, 711, 718, 724, 725, 726, 732, 737, 745, 750, 752, 757, 758, 764, 767, 775, 776, 779, 781, 782, 786, 790, 792, 794, 796, 798, 800, 809, 811, 812, 814, 815, 816, 821, 827, 834, 837, 843, 850, 852, 855, 856, 857, 864, 868, 871, 873, 874, 883, 887, 888, 890, 895, 896, 899, 907, 908, 910, 911, 913, 917, 918, 920, 921, 922, 923, 925, 927, 931, 932, 933, 934, 935, 938, 944, 949, 969, 978, 980, 987, 988, 989, 990, 992, 994, 996, 997, 999, 1000, 1002, 1007, 1010, 1011, 1017, 1022, 1033, 1036, 1040, 1048, 1055, 1058, 1063, 1066, 1075, 1078, 1081, 1093, 1108, 1129, 1140, 1171, 1178, 1195, 1205, 1234]

# %%
from collections import Counter

bool_list = []
for i in indices: 
    l =  base_list[i]
    c = Counter(l)
    if max([(c[i] / len(l)) for i in c]) < 0.98:
        bool_list.append(i)

# %%
bool_list
# Out:
# [186, 213, 1234]

# %%
samfile = pysam.AlignmentFile(bampath + "SRR7784795_align_dedup_sort.bam", "rb" )
pos = []
gap_delete = []
for pileupcolumn in samfile.pileup("NC_009942.1", 1, 11029):
    pos.append(pileupcolumn.n)
    if pileupcolumn.n >= 1:
        gap_delete.append(pileupcolumn.pos)
